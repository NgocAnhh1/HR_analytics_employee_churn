# %% [markdown]
# #**Employee Churn Analysis**

# %% [markdown]
# #**Exploratory Analysis**

# %% [markdown]
# ##Importing Modules

# %%
#import modules
import pandas  # for dataframes
import matplotlib.pyplot as plt # for plotting graphs
import seaborn as sns # for plotting graphs
# %matplotlib inline

# %% [markdown]
# ##Loading Dataset

# %%
data=pandas.read_csv('/content/drive/MyDrive/Project/HR_analytics_employee_churn.csv')

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left_company  promotion_last_5years  \
# 0                   3              0             1                      0
# 1                   6              0             1                      0
# 2                   4              0             1                      0
# 3                   5              0             1                      0
# 4                   3              0             1                      0
#
#   Department  salary
# 0      sales     low
# ...

# %%
data.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left_company  \
# 14994                   151                   3              0             1
# 14995                   160                   3              0             1
# 14996                   143                   3              0             1
# 14997                   280                   4              0             1
# 14998                   158                   3              0             1
#
#        promotion_last_5years Department salary
# 14994                      0    support    low
# 14995                      0    support    low
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left_company           14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# > Bộ dữ liệu này bao gồm ***14,999 mẫu*** và ***10 thuộc tính***, bao gồm *6 thuộc tính số nguyên, 2 thuộc tính số thực và 2 thuộc tính đối tượng*. **Không có giá trị trống trong bất kỳ cột nào.**
#
#
# *   satisfaction_level: Điểm hài lòng của nhân viên, dao động từ 0-1.
#
# *   last_evaluation: Đánh giá hiệu suất của nhân viên từ phía nhà tuyển dụng, cũng trong khoảng từ 0-1.
#
# *   number_projects: Số lượng dự án được giao cho một nhân viên.
#
# *   average_monthly_hours: Trung bình số giờ làm việc của nhân viên trong một tháng.
#
# *   time_spent_company: Thời gian làm việc trong công ty của nhân viên, tính bằng số năm.
#
# *   work_accident: Liệu nhân viên có bị tai nạn lao động hay không.
#
# *   promotion_last_5years: Liệu nhân viên có được thăng tiến trong 5 năm gần đây hay không.
#
# *   Departments: Phòng/bộ phận làm việc của nhân viên.
#
# *   Salary: Mức lương của nhân viên, có ba cấp độ là thấp, trung bình và cao.
#
# *   left: Liệu nhân viên đã rời công ty hay chưa.

# %% [markdown]
# ##Data Insights

# %%
left = data.groupby('left_company')
left.mean()
# Out:
# <ipython-input-11-bfe79d8c8599>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   left.mean()
#               satisfaction_level  last_evaluation  number_project  \
# left_company
# 0                       0.666810         0.715473        3.786664
# 1                       0.440098         0.718113        3.855503
#
#               average_montly_hours  time_spend_company  Work_accident  \
# left_company
# 0                       199.060203            3.380032       0.175009
# 1                       207.419210            3.876505       0.047326
#
#               promotion_last_5years
# left_company
# 0                          0.026251
# 1                          0.005321

# %%
data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident  left_company  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %% [markdown]
# ##Data Visualization

# %%
left_count=data.groupby('left_company').count()
plt.bar(left_count.index.values, left_count['satisfaction_level'])
plt.xlabel('Employees Left Company')
plt.ylabel('Number of Employees')
plt.show()

# %%
data.left_company.value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left_company, dtype: int64

# %% [markdown]
#  > Trong số khoảng 15,000 nhân viên, khoảng **3,571 người** đã rời công ty và **11,428 người** đã ở lại. Số lượng nhân viên đã rời đi chiếm ***23%*** tổng số nhân viên.

# %%
num_projects=data.groupby('number_project').count()
plt.bar(num_projects.index.values, num_projects['satisfaction_level'])
plt.xlabel('Number of Projects')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# > Phần lớn nhân viên đang tham gia làm việc trong dự án từ **3-5 dự án**.

# %%
time_spent=data.groupby('time_spend_company').count()
plt.bar(time_spent.index.values, time_spent['satisfaction_level'])
plt.xlabel('Number of Years Spend in Company')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# > Phần lớn nhân viên có kinh nghiệm **từ 2-4 năm**. Ngoài ra, có một khoảng cách lớn giữa nhân viên có kinh nghiệm 3 năm và 4 năm.

# %%
features=['number_project','time_spend_company','Work_accident','left_company', 'promotion_last_5years','Department','salary']
fig=plt.subplots(figsize=(10,15))
for i, j in enumerate(features):
    plt.subplot(4, 2, i+1)
    plt.subplots_adjust(hspace = 1.0)
    sns.countplot(x=j,data = data)
    plt.xticks(rotation=90)
    plt.title("No. of employee")
# Out:
# <ipython-input-19-c0d881fb7cd6>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(4, 2, i+1)

# %% [markdown]
# 1.   Phần lớn nhân viên đang tham gia làm việc trong dự án từ 3-5 dự án.
# 2.   Có một sự sụt giảm lớn giữa nhân viên có kinh nghiệm 3 năm và 4 năm.
# 3.   Số lượng nhân viên đã rời đi chiếm 23% tổng số nhân viên.
# 4.   Số lượng nhân viên được thăng chức trong 5 năm gần đây là rất ít.
# 5.   Phòng ban bán hàng có số lượng nhân viên lớn nhất, tiếp theo là phòng kỹ thuật và hỗ trợ.
# 6.   Phần lớn nhân viên đang nhận mức lương trung bình hoặc thấp.

# %%
fig=plt.subplots(figsize=(10,15))
for i, j in enumerate(features):
    plt.subplot(4, 2, i+1)
    plt.subplots_adjust(hspace = 1.0)
    sns.countplot(x=j,data = data, hue='left_company')
    plt.xticks(rotation=90)
    plt.title("No. of employee")
# Out:
# <ipython-input-24-d2bb84ce756a>:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(4, 2, i+1)

# %% [markdown]
# 1. Những nhân viên có số lượng dự án lớn hơn 5 đã rời công ty.
# Những nhân viên đã thực hiện 6 và 7 dự án đã rời công ty, có vẻ như họ bị quá tải công việc.
# 2. Những nhân viên có kinh nghiệm 5 năm rời công ty nhiều hơn do không có thăng tiến trong 5 năm qua, và những nhân viên có kinh nghiệm hơn 6 năm không rời đi vì tình cảm với công ty.
# 3. Những người được thăng tiến trong 5 năm qua không rời đi, tức là tất cả những người đã rời đi không được thăng tiến trong 5 năm trước đó.

# %% [markdown]
# > Các đặc trưng sau đây có ảnh hưởng mạnh đến việc nhân viên rời công ty:
#
# 1. Thăng tiến: Nhân viên có khả năng nghỉ việc cao hơn nếu họ không được thăng tiến trong 5 năm qua.
# 2. Thời gian làm việc trong công ty: Ở đây, thời điểm 3 năm dường như là một điểm quan trọng trong sự nghiệp của nhân viên. Hầu hết họ nghỉ việc xung quanh thời điểm 3 năm. Một điểm quan trọng khác là điểm 6 năm, khi nhân viên rất ít có khả năng nghỉ việc.
# 3. Số lượng dự án: Độ cam kết của nhân viên là yếu tố quan trọng khác ảnh hưởng đến việc nhân viên rời công ty. Nhân viên có 3-5 dự án thì ít có khả năng rời công ty. Nhân viên có ít hoặc nhiều dự án có khả năng rời đi.
# 4. Mức lương: Hầu hết những nhân viên nghỉ việc thuộc các nhóm lương trung bình hoặc thấp.

# %% [markdown]
# #**Cluster Analysis**

# %%
#import module
from sklearn.cluster import KMeans
# Filter data
left_emp =  data[['satisfaction_level', 'last_evaluation']][data.left_company == 1]
# Create groups using K-means clustering.
kmeans = KMeans(n_clusters = 3, random_state = 0).fit(left_emp)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Add new column "label" annd assign cluster labels.
left_emp['label'] = kmeans.labels_
# Draw scatter plot
plt.scatter(left_emp['satisfaction_level'], left_emp['last_evaluation'], c=left_emp['label'],cmap='Accent')
plt.xlabel('Satisfaction Level')
plt.ylabel('Last Evaluation')
plt.title('3 Clusters of employees who left')
plt.show()

# %% [markdown]
# > Nhân viên đã rời công ty có thể được nhóm thành 3 loại nhân viên:
#
# * Hài lòng cao và đánh giá cao (Được tô bằng màu xanh lá trong biểu đồ), cũng có thể gọi là "Những người chiến thắng" (Winners).
# * Hài lòng thấp và đánh giá cao (Được tô bằng màu xanh lam trong biểu đồ), cũng có thể gọi là "Cảm thấy thất vọng" (Frustrated).
# * Hài lòng vừa phải và đánh giá vừa phải (Được tô bằng màu xám trong biểu đồ), cũng có thể gọi là "Không phù hợp" (Bad match).

# %% [markdown]
# #**Building a Prediction Model**

# %% [markdown]
# ## Pre-Processing Data

# %%
# Import LabelEncoder
from sklearn import preprocessing
#creating labelEncoder
le = preprocessing.LabelEncoder()
# Converting string labels into numbers.
data['salary']=le.fit_transform(data['salary'])
data['Department']=le.fit_transform(data['Department'])

# %% [markdown]
# ## Split Train and Test Set

# %%
#Spliting data into Feature and
X=data[['satisfaction_level', 'last_evaluation', 'number_project',
       'average_montly_hours', 'time_spend_company', 'Work_accident',
       'promotion_last_5years', 'Department', 'salary']]
y=data['left_company']

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)  # 70% training and 30% test

# %% [markdown]
# ## Model Building

# %%
#Import Gradient Boosting Classifier model
from sklearn.ensemble import GradientBoostingClassifier

#Create Gradient Boosting Classifier
gb = GradientBoostingClassifier()

#Train the model using the training sets
gb.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = gb.predict(X_test)

# %% [markdown]
# # Evaluating Model Performance

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Model Precision
print("Precision:",metrics.precision_score(y_test, y_pred))
# Model Recall
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.9715555555555555
# Precision: 0.958252427184466
# Recall: 0.9207089552238806

# %% [markdown]
#  > Tỷ lệ phân loại là 97%, được coi là độ chính xác tốt.
